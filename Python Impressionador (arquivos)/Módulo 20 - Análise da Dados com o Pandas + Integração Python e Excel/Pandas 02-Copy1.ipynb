# %% [markdown]
# # pandas e csv
#
# ## Resumo
#
# Quase sempre quando formos "ler" um arquivo csv, vamos usar o pandas. É prático e bem eficiente.
#
# ## Funcionamento

# %% [raw]
# Forma mais básica: (muitas vezes não usaremos a forma mais básica)
# dataframe = pd.read_csv(arquivo_com_extensao)

# %% [markdown]
# - Vamos ler um arquivo real, com a Base de Dados de Vendas da Empresa "Contoso"

# %%
import pandas as pd

import tabula

# Ler a tabela em PDF
df = tabula.read_pdf('A.pdf', pages='all')

# Imprimir o conteúdo da tabela
print(df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 6
#       3 import tabula
#       5 # Ler a tabela em PDF
# ----> 6 df = tabula.read_pdf('A.pdf', pages='all')
#       8 # Imprimir o conteúdo da tabela
#       9 print(df)
#
# File c:\Users\GAMERX\AppData\Local\Programs\Python\Python311\Lib\site-packages\tabula\io.py:419, in read_pdf(input_path, output_format, encoding, java_options, pandas_options, multiple_tables, user_agent, use_raw_url, pages, guess, area, relative_area, lattice, stream, password, silent, columns, relative_columns, format, batch, output_path, options)
#     416 path, temporary = localize_file(input_path, user_agent, use_raw_url=use_raw_url)
#     418 if not os.path.exists(path):
# --> 419     raise FileNotFoundError(errno.ENOENT, os.strerror(errno.ENOENT), path)
#     421 if os.path.getsize(path) == 0:
# ...

# %%
import tabula
import pandas as pd

# # Ler a tabela em PDF com várias tabelas
# dfs = tabula.read_pdf('A.pdf', pages='all', multiple_tables=True)

# # Juntar as tabelas em um único objeto DataFrame
# df = pd.concat(dfs)

# # Definir títulos apenas para as colunas relevantes
# df.columns = ['ID', 'Produto', 'Quantidade']

# # Imprimir o objeto DataFrame resultante
# #print(df)
